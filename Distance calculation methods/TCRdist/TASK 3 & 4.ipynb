# %%
import pandas as pd
import numpy as np

df_alpha = pd.read_csv('cdr3_alpha_df.csv')
df_beta = pd.read_csv('cdr3_beta_df.csv')
df_combined = pd.read_csv('cdr3_alpha_beta_df.csv')

# %%
df = pd.read_csv('/Users/shalomifernandes/Desktop/UOB/TB2/DSMP/vdjdb.csv')
df.head()
# Out:
#    complex.id gene                  cdr3       v.segm      j.segm  \
# 0           1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1           1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2           0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3           2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4           2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
#
#        species     mhc.a mhc.b mhc.class antigen.epitope  ... antigen.species  \
# 0  HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...           HIV-1
# 1  HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...           HIV-1
# 2  HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...           HIV-1
# 3  HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...           HIV-1
# 4  HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...           HIV-1
#
#     reference.id                                             method  \
# ...

# %%
df_alpha.head()
# Out:
#    complex.id       cdr3_a_aa         v_a_gene   j_a_gene      species  \
# 0           1   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01  HomoSapiens
# 1           2  CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01  HomoSapiens
# 2           4   CAYRPPGTYKYIF  TRAV38-2/DV8*01  TRAJ40*01  HomoSapiens
# 3           5   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01  HomoSapiens
# 4           6  CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01  HomoSapiens
#
#       mhc.a mhc.b mhc.class   epitope  vdjdb.score
# 0  HLA-B*08   B2M      MHCI  FLKEKGGL            2
# 1  HLA-B*08   B2M      MHCI  FLKEKGGL            2
# 2  HLA-B*08   B2M      MHCI  FLKEKGGL            2
# 3  HLA-B*08   B2M      MHCI  FLKEQGGL            2
# 4  HLA-B*08   B2M      MHCI  FLKEQGGL            2

# %%
df_beta.head()
# Out:
#    complex.id             cdr3_b_aa   v_b_gene    j_b_gene      species  \
# 0           1  CASSYLPGQGDHYSNQPQHF  TRBV13*01  TRBJ1-5*01  HomoSapiens
# 1           2   CASSFEPGQGFYSNQPQHF  TRBV13*01  TRBJ1-5*01  HomoSapiens
# 2           3  CASSYEPGQVSHYSNQPQHF  TRBV13*01  TRBJ1-5*01  HomoSapiens
# 3           4        CASSALASLNEQFF  TRBV14*01  TRBJ2-1*01  HomoSapiens
# 4           5  CASSYLPGQGDHYSNQPQHF  TRBV13*01  TRBJ1-5*01  HomoSapiens
#
#       mhc.a mhc.b mhc.class   epitope  vdjdb.score
# 0  HLA-B*08   B2M      MHCI  FLKEKGGL            2
# 1  HLA-B*08   B2M      MHCI  FLKEKGGL            2
# 2  HLA-B*08   B2M      MHCI  FLKEKGGL            2
# 3  HLA-B*08   B2M      MHCI  FLKEKGGL            2
# 4  HLA-B*08   B2M      MHCI  FLKEQGGL            2

# %%
df_combined.head()
# Out:
#    complex.id       cdr3_a_aa         v_a_gene   j_a_gene      species  \
# 0           1   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01  HomoSapiens
# 1           2  CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01  HomoSapiens
# 2           4   CAYRPPGTYKYIF  TRAV38-2/DV8*01  TRAJ40*01  HomoSapiens
# 3           5   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01  HomoSapiens
# 4           6  CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01  HomoSapiens
#
#       mhc.a mhc.b mhc.class   epitope  vdjdb.score             cdr3_b_aa  \
# 0  HLA-B*08   B2M      MHCI  FLKEKGGL            2  CASSYLPGQGDHYSNQPQHF
# 1  HLA-B*08   B2M      MHCI  FLKEKGGL            2   CASSFEPGQGFYSNQPQHF
# 2  HLA-B*08   B2M      MHCI  FLKEKGGL            2        CASSALASLNEQFF
# 3  HLA-B*08   B2M      MHCI  FLKEQGGL            2  CASSYLPGQGDHYSNQPQHF
# 4  HLA-B*08   B2M      MHCI  FLKEQGGL            2   CASSFEPGQGFYSNQPQHF
#
#     v_b_gene    j_b_gene
# 0  TRBV13*01  TRBJ1-5*01
# 1  TRBV13*01  TRBJ1-5*01
# ...

# %%
human_alpha = df_alpha[df_alpha['species'] == 'HomoSapiens']
human_beta = df_beta[df_beta['species'] == 'HomoSapiens']
human = df_combined[df_combined['species'] == 'HomoSapiens']
mouse_alpha = df_alpha[df_alpha['species'] == 'MusMusculus']
mouse_beta = df_beta[df_beta['species'] == 'MusMusculus']
mouse = df_combined[df_combined['species'] == 'MusMusculus']

# %%
human_alpha.head(), human_beta.head(), human.head()
# Out:
# (   complex.id       cdr3_a_aa         v_a_gene   j_a_gene      species  \
#  0           1   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01  HomoSapiens
#  1           2  CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01  HomoSapiens
#  2           4   CAYRPPGTYKYIF  TRAV38-2/DV8*01  TRAJ40*01  HomoSapiens
#  3           5   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01  HomoSapiens
#  4           6  CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01  HomoSapiens
#
#        mhc.a mhc.b mhc.class   epitope  vdjdb.score
#  0  HLA-B*08   B2M      MHCI  FLKEKGGL            2
#  1  HLA-B*08   B2M      MHCI  FLKEKGGL            2
#  2  HLA-B*08   B2M      MHCI  FLKEKGGL            2
#  3  HLA-B*08   B2M      MHCI  FLKEQGGL            2
#  4  HLA-B*08   B2M      MHCI  FLKEQGGL            2  ,
#     complex.id             cdr3_b_aa   v_b_gene    j_b_gene      species  \
#  0           1  CASSYLPGQGDHYSNQPQHF  TRBV13*01  TRBJ1-5*01  HomoSapiens
# ...

# %%
mouse_alpha.head(), mouse_beta.head(), mouse.head()
# Out:
# (    complex.id         cdr3_a_aa     v_a_gene   j_a_gene      species  mhc.a  \
#  38         106  CAMRGDYGGSGNKLIF    TRAV16*01  TRAJ32*01  MusMusculus  H-2Kb
#  40         108      CAVSGFASALTF   TRAV9-4*01  TRAJ35*01  MusMusculus  H-2Kb
#  42         110     CAARYQGGRALIF  TRAV14-1*01  TRAJ15*01  MusMusculus  H-2Kb
#  44         112      CAVSGFASALTF   TRAV9-4*01  TRAJ35*01  MusMusculus  H-2Kb
#  45         113  CAMRGDYGGSGNKLIF    TRAV16*01  TRAJ32*01  MusMusculus  H-2Kb
#
#     mhc.b mhc.class   epitope  vdjdb.score
#  38   B2M      MHCI  INFDFNTI            3
#  40   B2M      MHCI  SIYRYYGL            3
#  42   B2M      MHCI  KVITFIDL            3
#  44   B2M      MHCI  EQYKFYSV            3
#  45   B2M      MHCI  RGYVYQGL            3  ,
#      complex.id           cdr3_b_aa     v_b_gene    j_b_gene      species  \
#  42         105       CASGGQGRAEQFF  TRBV13-2*01  TRBJ2-1*01  MusMusculus
#  43         106      CTCSADRVGNTLYF     TRBV1*01  TRBJ1-3*01  MusMusculus
# ...

# %%
# Create a dictionary with each DataFrame you want to check
dataframes = {
    'human': human,
    'human_alpha': human_alpha,
    'human_beta': human_beta,
    'mouse': mouse,
    'mouse_alpha': mouse_alpha,
    'mouse_beta': mouse_beta
}

# Initialize an empty dictionary to store the value counts for each species
species_value_counts = {}

# Loop through the dictionary to get value counts for the 'species' column in each DataFrame
for key, df in dataframes.items():
    species_value_counts[key] = df['species'].value_counts()

# species_value_counts now contains the value counts for the 'species' column from each DataFrame
species_value_counts
# Out:
# {'human': species
#  HomoSapiens    1868
#  Name: count, dtype: int64,
#  'human_alpha': species
#  HomoSapiens    1941
#  Name: count, dtype: int64,
#  'human_beta': species
#  HomoSapiens    1966
#  Name: count, dtype: int64,
#  'mouse': species
#  MusMusculus    902
#  Name: count, dtype: int64,
#  'mouse_alpha': species
#  MusMusculus    902
#  Name: count, dtype: int64,
#  'mouse_beta': species
#  MusMusculus    925
#  Name: count, dtype: int64}

# %%
# Create a dictionary with each DataFrame you want to check
dataframes = {
    'human': human,
    'human_alpha': human_alpha,
    'human_beta': human_beta,
    'mouse': mouse,
    'mouse_alpha': mouse_alpha,
    'mouse_beta': mouse_beta
}

# Initialize an empty dictionary to store the value counts for each species
epitope_value_counts = {}

# Loop through the dictionary to get value counts for the 'species' column in each DataFrame
for key, df in dataframes.items():
    epitope_value_counts[key] = df['epitope'].value_counts()

# species_value_counts now contains the value counts for the 'epitope' column from each DataFrame
epitope_value_counts
# Out:
# {'human': epitope
#  NLVPMVATV         441
#  GILGFVFTL         246
#  TFEYVSQPFLMDLE     87
#  GLCTLVAML          70
#  YLQPRTFLL          64
#                   ...
#  QPFPQPELPYP         1
#  APQPELPYPQPG        1
#  ELAGIGALTV          1
#  KVDPIGHVY           1
#  YPLHEQHGM           1
#  Name: count, Length: 330, dtype: int64,
#  'human_alpha': epitope
#  NLVPMVATV         448
#  GILGFVFTL         246
#  TFEYVSQPFLMDLE     87
#  GLCTLVAML          70
#  YLQPRTFLL          64
#                   ...
#  YLSNIIPAL           1
#  QLCDVMFYL           1
#  YLYDRLLRV           1
#  LYPEFIASI           1
#  KRWIILGLNK          1
#  Name: count, Length: 337, dtype: int64,
#  'human_beta': epitope
#  NLVPMVATV         453
#  GILGFVFTL         250
#  TFEYVSQPFLMDLE     87
#  GLCTLVAML          72
#  RPRGEVRFL          68
#                   ...
#  QTNPVTLQY           1
#  TLYSLTLLY           1
#  AVVQSELPYPEGS       1
#  CISSCNPNL           1
#  RLLMLFAKDVVSRN      1
# ...

# %%
'''# Filter out epitopes with counts less than 10 from each DataFrame
for key, df in dataframes.items():
    # Calculate value counts for the epitope column
    epitope_counts = df['epitope'].value_counts()
    
    # Find epitopes with counts of 10 or more
    epitopes_to_keep = epitope_counts[epitope_counts >= 10].index
    
    # Filter the DataFrame to only include rows with these epitopes
    dataframes[key] = df[df['epitope'].isin(epitopes_to_keep)]

# Now the dataframes dictionary contains the filtered DataFrames'''
# Out:
# "# Filter out epitopes with counts less than 10 from each DataFrame\nfor key, df in dataframes.items():\n    # Calculate value counts for the epitope column\n    epitope_counts = df['epitope'].value_counts()\n    \n    # Find epitopes with counts of 10 or more\n    epitopes_to_keep = epitope_counts[epitope_counts >= 10].index\n    \n    # Filter the DataFrame to only include rows with these epitopes\n    dataframes[key] = df[df['epitope'].isin(epitopes_to_keep)]\n\n# Now the dataframes dictionary contains the filtered DataFrames"

# %%
'''# Assuming 'dataframes' is already updated as per the previous steps

# Update the individual DataFrame variables
human = dataframes['human']
human_alpha = dataframes['human_alpha']
human_beta = dataframes['human_beta']
mouse = dataframes['mouse']
mouse_alpha = dataframes['mouse_alpha']
mouse_beta = dataframes['mouse_beta']

# Now the individual variables have been updated with the filtered data'''# Assuming 'dataframes' is already updated as per the previous steps
# Out:
# "# Assuming 'dataframes' is already updated as per the previous steps\n\n# Update the individual DataFrame variables\nhuman = dataframes['human']\nhuman_alpha = dataframes['human_alpha']\nhuman_beta = dataframes['human_beta']\nmouse = dataframes['mouse']\nmouse_alpha = dataframes['mouse_alpha']\nmouse_beta = dataframes['mouse_beta']\n\n# Now the individual variables have been updated with the filtered data"

# %%
print(mouse['epitope'])
# Out:
# 38        INFDFNTI
# 40        SIYRYYGL
# 42        KVITFIDL
# 44        EQYKFYSV
# 45        RGYVYQGL
#            ...
# 2523      SIINFEKL
# 2524      SIINFEKL
# 2578    VVVGAVGVGK
# 2579     VVGAVGVGK
# 2580    VVVGADGVGK
# Name: epitope, Length: 902, dtype: object

# %%
dataframes = {
    'human': human,
    'human_alpha': human_alpha,
    'human_beta': human_beta,
    'mouse': mouse,
    'mouse_alpha': mouse_alpha,
    'mouse_beta': mouse_beta
}

# Initialize dictionaries to store the counts of duplicates and missing values
duplicate_counts = {}
missing_value_counts = {}

# Loop through the dataframes to calculate counts of duplicates and missing values
for key, df in dataframes.items():
    # Count of duplicate rows
    duplicate_counts[key] = df.duplicated().sum()
    
    # Count of missing values for each column
    missing_value_counts[key] = df.isnull().sum()

# Now, duplicate_counts contains the counts of duplicates for each DataFrame
# and missing_value_counts contains the counts of missing values for each DataFrame
duplicate_counts, missing_value_counts
# Out:
# ({'human': 0,
#   'human_alpha': 0,
#   'human_beta': 0,
#   'mouse': 0,
#   'mouse_alpha': 0,
#   'mouse_beta': 0},
#  {'human': complex.id     0
#   cdr3_a_aa      0
#   v_a_gene       0
#   j_a_gene       0
#   species        0
#   mhc.a          0
#   mhc.b          0
#   mhc.class      0
#   epitope        0
#   vdjdb.score    0
#   cdr3_b_aa      0
#   v_b_gene       0
#   j_b_gene       0
#   dtype: int64,
#   'human_alpha': complex.id     0
#   cdr3_a_aa      0
#   v_a_gene       0
#   j_a_gene       0
#   species        0
#   mhc.a          0
#   mhc.b          0
#   mhc.class      0
#   epitope        0
#   vdjdb.score    0
#   dtype: int64,
#   'human_beta': complex.id     0
#   cdr3_b_aa      0
#   v_b_gene       0
#   j_b_gene       0
#   species        0
#   mhc.a          0
#   mhc.b          0
#   mhc.class      0
#   epitope        0
#   vdjdb.score    0
#   dtype: int64,
#   'mouse': complex.id     0
#   cdr3_a_aa      0
#   v_a_gene       0
#   j_a_gene       0
# ...

# %% [markdown]
# # TCR DISTANCE CALCULATION FOR MOUSE SPECIES FOR ALPHA, BETA AND COMBINED ALPHA AND BETA CHAINS

# %% [markdown]
# TCR DISTANCE CALCULATION FOR MOUSE SPECIES FOR ALPHA CHAIN

# %%
import pandas as pd
from tcrdist.repertoire import TCRrep

tr = TCRrep(cell_df = mouse_alpha, 
            organism = 'mouse', 
            chains = ['alpha'], 
            db_file = 'alphabeta_gammadelta_db.tsv')

tr.pw_alpha
mouse_alpha_matrix = tr.pw_cdr3_a_aa
mouse_alpha_matrix
# Out:
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:791: UserWarning: No 'count' column provided; count column set to 1
#   warnings.warn("No 'count' column provided; count column set to 1")
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:792: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.cell_df['count'] = 1
# array([[ 0, 35, 32, ..., 24, 23, 40],
#        [35,  0, 24, ..., 36, 31, 40],
#        [32, 24,  0, ..., 28, 36, 35],
#        ...,
# ...

# %% [markdown]
# TCR DISTANCE CALCULATION FOR MOUSE SPECIES FOR BETA CHAIN

# %%
import pandas as pd
from tcrdist.repertoire import TCRrep

tr = TCRrep(cell_df = mouse_beta, 
            organism = 'mouse', 
            chains = ['beta'], 
            db_file = 'alphabeta_gammadelta_db.tsv')

tr.pw_beta
mouse_beta_matrix = tr.pw_cdr3_b_aa
mouse_beta_matrix
# Out:
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:791: UserWarning: No 'count' column provided; count column set to 1
#   warnings.warn("No 'count' column provided; count column set to 1")
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:792: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.cell_df['count'] = 1
# array([[ 0, 35, 24, ..., 20, 20, 37],
#        [35,  0, 24, ..., 34, 28, 30],
#        [24, 24,  0, ..., 36, 36, 40],
#        ...,
# ...

# %% [markdown]
# TCR DISTANCE CALCULATION FOR MOUSE SPECIES FOR ALPHA AND BETA COMBINED CHAIN

# %%
from tcrdist.repertoire import TCRrep

tr = TCRrep(cell_df = mouse, 
            organism = 'mouse', 
            chains = ['alpha','beta'], 
            db_file = 'alphabeta_gammadelta_db.tsv')

tr.pw_alpha
tr.pw_beta
tr.pw_cdr3_a_aa
mouse_matrix = tr.pw_cdr3_b_aa
mouse_matrix
# Out:
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:791: UserWarning: No 'count' column provided; count column set to 1
#   warnings.warn("No 'count' column provided; count column set to 1")
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:792: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.cell_df['count'] = 1
# array([[ 0, 24, 36, ..., 34, 28, 30],
#        [24,  0, 44, ..., 36, 36, 40],
#        [36, 44,  0, ..., 48, 48, 48],
#        ...,
# ...

# %% [markdown]
# # TCR DISTANCE CALCULATION FOR HUMAN SPECIES FOR ALPHA, BETA AND COMBINED ALPHA AND BETA CHAINS

# %% [markdown]
# TCR DISTANCE CALCULATION FOR HUMAN SPECIES FOR ALPHA CHAIN

# %%
#TCR DISTANCE CALCULATION FOR HUMAN SPECIES FOR ALPHA CHAIN
import pandas as pd
from tcrdist.repertoire import TCRrep

tr = TCRrep(cell_df = human_alpha, 
            organism = 'human', 
            chains = ['alpha'], 
            db_file = 'alphabeta_gammadelta_db.tsv')

tr.pw_alpha
human_alpha_matrix = tr.pw_cdr3_a_aa
human_alpha_matrix
# Out:
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:791: UserWarning: No 'count' column provided; count column set to 1
#   warnings.warn("No 'count' column provided; count column set to 1")
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:792: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.cell_df['count'] = 1
# array([[ 0, 29, 20, ..., 42, 46, 29],
#        [29,  0, 26, ..., 30, 35, 30],
#        [20, 26,  0, ..., 36, 40, 23],
#        ...,
# ...

# %% [markdown]
# TCR DISTANCE CALCULATION FOR HUMAN SPECIES FOR BETA CHAIN

# %%
import pandas as pd
from tcrdist.repertoire import TCRrep

tr = TCRrep(cell_df = human_beta, 
            organism = 'human', 
            chains = ['beta'], 
            db_file = 'alphabeta_gammadelta_db.tsv')

tr.pw_beta
human_beta_matrix = tr.pw_cdr3_b_aa
human_beta_matrix
# Out:
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:791: UserWarning: No 'count' column provided; count column set to 1
#   warnings.warn("No 'count' column provided; count column set to 1")
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:792: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.cell_df['count'] = 1
# array([[ 0, 13, 12, ..., 48, 47, 46],
#        [13,  0, 13, ..., 44, 41, 42],
#        [12, 13,  0, ..., 48, 48, 46],
#        ...,
# ...

# %% [markdown]
# TCR DISTANCE CALCULATION FOR HUMAN SPECIES FOR ALPHA AND BETA COMBINED CHAIN

# %%
import pandas as pd
from tcrdist.repertoire import TCRrep

tr = TCRrep(cell_df = human, 
            organism = 'human', 
            chains = ['alpha','beta'], 
            db_file = 'alphabeta_gammadelta_db.tsv')

tr.pw_alpha
tr.pw_beta
tr.pw_cdr3_a_aa
human_matrix = tr.pw_cdr3_b_aa
human_matrix
# Out:
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:791: UserWarning: No 'count' column provided; count column set to 1
#   warnings.warn("No 'count' column provided; count column set to 1")
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:792: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.cell_df['count'] = 1
# array([[ 0, 13, 44, ..., 48, 47, 46],
#        [13,  0, 44, ..., 44, 41, 42],
#        [44, 44,  0, ..., 19, 23, 28],
#        ...,
# ...

# %% [markdown]
# # DIMENSIONALITY REDUCTION:

# %% [markdown]
# DIMENSIONALITY REDUCTION FOR MOUSE SPECIES FOR ALPHA CHAIN

# %%
import seaborn as sns
from umap import UMAP
import matplotlib.pyplot as plt

# Assuming your distance matrix is called `mouse_alpha_matrix`
# and the corresponding epitopes are in `mouse_alpha_epitopes`
# Assuming 'mouse_alpha' is your DataFrame with TCR data for the alpha chains of human species
# The DataFrame has a column 'epitope' which contains the epitope information for each TCR
mouse_alpha_epitopes = mouse_alpha['epitope']

# Apply UMAP dimensionality reduction
reducer = UMAP(random_state=42)
mouse_alpha_embedding = reducer.fit_transform(mouse_alpha_matrix)

# Create a DataFrame for the reduced data
mouse_alpha_embedding_df = pd.DataFrame(mouse_alpha_embedding, columns=['UMAP1', 'UMAP2'])
mouse_alpha_embedding_df['epitope'] = mouse_alpha_epitopes.values  # Ensure this is the correct corresponding epitope information

# Plot using seaborn
plt.figure(figsize=(12, 10))
sns.scatterplot(data=mouse_alpha_embedding_df, x='UMAP1', y='UMAP2', hue='epitope', palette='Spectral', alpha=0.6)

# Add a title and labels
plt.title('UMAP Projection of Mouse Alpha TCRs')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')

# Move the legend out of the plot
plt.legend(title='Epitope', loc='upper center', bbox_to_anchor=(0.5, -0.05),
           fancybox=True, shadow=True, ncol=5)

plt.show()
# Out:
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %% [markdown]
# DIMENSIONALITY REDUCTION FOR MOUSE SPECIES FOR BETA CHAIN

# %%
import seaborn as sns
from umap import UMAP

# Assuming your distance matrix is called `mouse_beta_matrix`
# and the corresponding epitopes are in `mouse_beta_epitopes`
# Assuming 'mouse_beta' is your DataFrame with TCR data for the alpha chains of human species
# The DataFrame has a column 'epitope' which contains the epitope information for each TCR
mouse_beta_epitopes = mouse_beta['epitope']

# Apply UMAP dimensionality reduction
reducer = UMAP(random_state=42)
mouse_beta_embedding = reducer.fit_transform(mouse_beta_matrix)

# Create a DataFrame for the reduced data
mouse_beta_embedding_df = pd.DataFrame(mouse_beta_embedding, columns=['UMAP1', 'UMAP2'])
mouse_beta_embedding_df['epitope'] = mouse_beta_epitopes.values  # Ensure this is the correct corresponding epitope information

# Plot using seaborn
plt.figure(figsize=(12, 10))
sns.scatterplot(data=mouse_beta_embedding_df, x='UMAP1', y='UMAP2', hue='epitope', palette='Spectral', alpha=0.6)

# Add a title and labels
plt.title('UMAP Projection of Mouse Beta TCRs')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')

# Move the legend out of the plot
plt.legend(title='Epitope', loc='upper center', bbox_to_anchor=(0.5, -0.05),
           fancybox=True, shadow=True, ncol=5)

plt.show()
# Out:
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %% [markdown]
# DIMENSIONALITY REDUCTION FOR MOUSE SPECIES FOR COMBINED ALPHA AND BETA CHAINS

# %%
import seaborn as sns
from umap import UMAP

# Assuming your distance matrix is called `mouse_matrix`
# and the corresponding epitopes are in `mouse_combined_epitopes`
# Assuming 'mouse' is your DataFrame with TCR data for the alpha chains of human species
# The DataFrame has a column 'epitope' which contains the epitope information for each TCR
mouse_combined_epitopes = mouse['epitope']

# Apply UMAP dimensionality reduction
reducer = UMAP(random_state=42)
mouse_combined_embedding = reducer.fit_transform(mouse_matrix)

# Create a DataFrame for the reduced data
mouse_combined_embedding_df = pd.DataFrame(mouse_combined_embedding, columns=['UMAP1', 'UMAP2'])
mouse_combined_embedding_df['epitope'] = mouse_combined_epitopes.values  # Ensure this is the correct corresponding epitope information

# Plot using seaborn
plt.figure(figsize=(12, 10))
sns.scatterplot(data=mouse_combined_embedding_df, x='UMAP1', y='UMAP2', hue='epitope', palette='Spectral', alpha=0.6)

# Add a title and labels
plt.title('UMAP Projection of Mouse Combined TCRs')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')

# Move the legend out of the plot
plt.legend(title='Epitope', loc='upper center', bbox_to_anchor=(0.5, -0.05),
           fancybox=True, shadow=True, ncol=5)

plt.show()
# Out:
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %% [markdown]
# DIMENSIONALITY REDUCTION FOR HUMAN SPECIES FOR ALPHA CHAIN

# %%
import seaborn as sns
from umap import UMAP

# Assuming your distance matrix is called `human_alpha_matrix`
# and the corresponding epitopes are in `human_alpha_epitopes`
# Assuming 'human_alpha' is your DataFrame with TCR data for the alpha chains of human species
# The DataFrame has a column 'epitope' which contains the epitope information for each TCR
human_alpha_epitopes = human_alpha['epitope']

# Apply UMAP dimensionality reduction
reducer = UMAP(random_state=42)
human_alpha_embedding = reducer.fit_transform(human_alpha_matrix)

# Create a DataFrame for the reduced data
human_alpha_embedding_df = pd.DataFrame(human_alpha_embedding, columns=['UMAP1', 'UMAP2'])
human_alpha_embedding_df['epitope'] = human_alpha_epitopes.values  # Ensure this is the correct corresponding epitope information

# Plot using seaborn
plt.figure(figsize=(12, 10))
sns.scatterplot(data=human_alpha_embedding_df, x='UMAP1', y='UMAP2', hue='epitope', palette='Spectral', alpha=0.6)

# Add a title and labels
plt.title('UMAP Projection of Human Alpha TCRs')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')

# Move the legend out of the plot
plt.legend(title='Epitope', loc='upper center', bbox_to_anchor=(0.5, -0.05),
           fancybox=True, shadow=True, ncol=5)

plt.show()
# Out:
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %% [markdown]
# DIMENSIONALITY REDUCTION FOR HUMAN SPECIES FOR BETA CHAIN

# %%
import seaborn as sns
from umap import UMAP

# Assuming your distance matrix is called `human_beta_matrix`
# and the corresponding epitopes are in `human_beta_epitopes`
# Assuming 'human_beta' is your DataFrame with TCR data for the alpha chains of human species
# The DataFrame has a column 'epitope' which contains the epitope information for each TCR
human_beta_epitopes = human_beta['epitope']

# Apply UMAP dimensionality reduction
reducer = UMAP(random_state=42)
human_beta_embedding = reducer.fit_transform(human_beta_matrix)

# Create a DataFrame for the reduced data
human_beta_embedding_df = pd.DataFrame(human_beta_embedding, columns=['UMAP1', 'UMAP2'])
human_beta_embedding_df['epitope'] = human_beta_epitopes.values  # Ensure this is the correct corresponding epitope information

# Plot using seaborn
plt.figure(figsize=(12, 10))
sns.scatterplot(data=human_beta_embedding_df, x='UMAP1', y='UMAP2', hue='epitope', palette='Spectral', alpha=0.6)

# Add a title and labels
plt.title('UMAP Projection of Human Beta TCRs')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')

# Move the legend out of the plot
plt.legend(title='Epitope', loc='upper center', bbox_to_anchor=(0.5, -0.05),
           fancybox=True, shadow=True, ncol=5)

plt.show()
# Out:
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %% [markdown]
# DIMENSIONALITY REDUCTION FOR HUMAN SPECIES FOR COMBINED ALPHA AND BETA CHAINS

# %%
import seaborn as sns
from umap import UMAP

# Assuming your distance matrix is called `human_matrix`
# and the corresponding epitopes are in `human_combined_epitopes`
# Assuming 'human' is your DataFrame with TCR data for the alpha chains of human species
# The DataFrame has a column 'epitope' which contains the epitope information for each TCR
human_combined_epitopes = human['epitope']

# Apply UMAP dimensionality reduction
reducer = UMAP(random_state=42)
human_combined_embedding = reducer.fit_transform(human_matrix)

# Create a DataFrame for the reduced data
human_combined_embedding_df = pd.DataFrame(human_combined_embedding, columns=['UMAP1', 'UMAP2'])
human_combined_embedding_df['epitope'] = human_combined_epitopes.values  # Ensure this is the correct corresponding epitope information

# Plot using seaborn
plt.figure(figsize=(12, 10))
sns.scatterplot(data=human_combined_embedding_df, x='UMAP1', y='UMAP2', hue='epitope', palette='Spectral', alpha=0.6)

# Add a title and labels
plt.title('UMAP Projection of Human Combined TCRs')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')

# Move the legend out of the plot
plt.legend(title='Epitope', loc='upper center', bbox_to_anchor=(0.5, -0.05),
           fancybox=True, shadow=True, ncol=5)

plt.show()
# Out:
# /Users/shalomifernandes/anaconda3/lib/python3.11/site-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
